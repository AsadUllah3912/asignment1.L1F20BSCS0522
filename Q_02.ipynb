# %%
import pandas as pd
df=pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
groupby_state=df['diagnosis'].groupby(df['state'])

# %%
groupby_state

# %%
groupby_state.value_counts()
# Out:
# state      diagnosis
# benign     tuberculoma                                       14
#            granuloma                                          8
#            inflammatory mass                                  4
#            unknown                                            4
#            pulmonary tuberculosis                             3
#            Cryptococcosis                                     2
#            Inflammatory mass                                  2
#            hamartoma                                          2
#            lung abscess                                       2
#            pulmonary hematoma                                 2
#            sclerosing hemangioma                              2
#            susp. inflammatory mass                            2
#            calcified granuloma                                1
#            organiging pneumonia                               1
# ...

# %%
import matplotlib as plt

# %%
from matplotlib import pyplot

# %%
plt.pyplot.pie(groupby_state.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0xa3dc05f5b0>,
# ...
#  [Text(1.0554422683381766, 0.30990582150899426, ''),
#   Text(0.8164575228681187, 0.7371547417958156, ''),
#   Text(0.613457518489472, 0.913055240940404, ''),
#   Text(0.45695649780118314, 1.000595202425675, ''),
#   Text(0.30990579680458497, 1.0554422755920456, ''),
#   Text(0.2008267884988962, 1.0815121825579312, ''),
#   Text(0.11200527086265337, 1.0942827876280354, ''),
#   Text(0.022438376629775863, 1.0997711213039831, ''),
#   Text(-0.06727784129722303, 1.0979406596307406, ''),
#   Text(-0.1565463362912849, 1.0888035840287156, ''),
#   Text(-0.24477304124759505, 1.0724207002284147, ''),
#   Text(-0.33137082200214407, 1.0489010336183409, ''),
#   Text(-0.39490298299866605, 1.0266701680767565, ''),
#   Text(-0.436450768946483, 1.009708238198552, ''),
#   Text(-0.47727212566370353, 0.9910657486082596, ''),
#   Text(-0.5172991100308246, 0.9707737278899327, ''),
#   Text(-0.55646510108272, 0.9488659501093917, ''),
# ...
