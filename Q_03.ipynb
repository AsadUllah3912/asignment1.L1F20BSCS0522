# %%
import pandas as pd
df=pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
groupby_gender=df['diagnosis'].groupby(df['gender'])

# %%
groupby_gender

# %%
groupby_gender.value_counts()
# Out:
# gender  diagnosis
# Female  lung cancer                                       32
#         lung cancer(adenocarcinoma)                       15
#         tuberculoma                                        5
#         lung cancer(bronchioloalveolar cell carcinoma)     4
#         unknown                                            4
#         metastasis of colon cancer                         3
#         Cryptococcosis                                     2
#         Inflammatory mass                                  2
#         granuloma                                          2
#         hamartoma                                          2
#         inflammatory mass                                  2
#         sclerosing hemangioma                              2
#         lung abscess                                       1
#         lung canceror metastasis                           1
#         metastasis of ovarian cancer                       1
# ...

# %%
import matplotlib as plt

# %%
from matplotlib import pyplot

# %%
plt.pyplot.pie(groupby_gender.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x8e14e5f5b0>,
# ...
#  [Text(0.8738257943595382, 0.668153037194266, ''),
#   Text(-0.044867434978757045, 1.0990845796745705, ''),
#   Text(-0.47727209811659155, 0.9910657618742497, ''),
#   Text(-0.6501892335768956, 0.8872733291047856, ''),
#   Text(-0.7857105690377114, 0.7698434267449686, ''),
#   Text(-0.8872733100813132, 0.6501892595370596, ''),
#   Text(-0.9488659476672029, 0.5564651052470595, ''),
#   Text(-0.9910657465136294, 0.4772721300132477, ''),
#   Text(-1.0266701663436242, 0.39490298750446956, ''),
#   Text(-1.0554422656179756, 0.30990583077314776, ''),
#   Text(-1.0771905707634313, 0.22284630187273302, ''),
#   Text(-1.0917703503977356, 0.13430376760316826, ''),
#   Text(-1.0979406593354748, 0.06727784611581497, ''),
#   Text(-1.099771120614647, 0.02243841041615243, ''),
#   Text(-1.0997711214024597, -0.022438371803150718, ''),
#   Text(-1.0979406616976015, -0.0672778075670808, ''),
#   Text(-1.094282788119599, -0.11200526606011468, ''),
# ...
